# %%
import pandas as pd

# %%
df = pd.read_csv('../data/total_count.csv')
df
# Out:
#                날짜        번호판  일일주행거리   누적주행거리          정보발생일시  차량속도  RPM
# 0        20221201  부산70자1854       0    66443  22120105071500     0  193  \
# 1        20221201  부산70자1854       0    66443  22120105071600     0  388
# 2        20221201  부산70자1854       0    66443  22120105071700     0  777
# 3        20221201  부산70자1854       0    66443  22120105071800     0  638
# 4        20221201  부산70자1854       0    66443  22120105071900     0  461
# ...           ...        ...     ...      ...             ...   ...  ...
# 5948207  20221231  부산70자1894     176  3095705  22123121033800     0  331
# 5948208  20221231  부산70자1894     176  3095705  22123121033900     0   59
# 5948209  20221231  부산70자1894     176  3095705  22123121034000     0    0
# 5948210  20221231  부산70자1894     176  3095705  22123121034100     0    0
# 5948211  20221231  부산70자1894     176  3095705  22123121034200     0    0
#
#          브레이크       GPS_X      GPS_Y  방위각  가속도_X  가속도_Y  급가속  급출발  급감속  급정지
# ...

# %%
license = df['번호판'].drop_duplicates()
license
# Out:
# 0          부산70자1854
# 1436759    부산70자1860
# 2873328    부산70자1893
# 4359153    부산70자1894
# Name: 번호판, dtype: object

# %%
bus_1854 = df.query('번호판 == "부산70자1854"')
bus_1854
# Out:
#                날짜        번호판  일일주행거리  누적주행거리          정보발생일시  차량속도  RPM  브레이크
# 0        20221201  부산70자1854       0   66443  22120105071500     0  193     0  \
# 1        20221201  부산70자1854       0   66443  22120105071600     0  388     0
# 2        20221201  부산70자1854       0   66443  22120105071700     0  777     0
# 3        20221201  부산70자1854       0   66443  22120105071800     0  638     0
# 4        20221201  부산70자1854       0   66443  22120105071900     0  461     0
# ...           ...        ...     ...     ...             ...   ...  ...   ...
# 1436754  20221231  부산70자1854      44   72362  22123122521400     0  557     1
# 1436755  20221231  부산70자1854      44   72362  22123122521500     0  223     1
# 1436756  20221231  부산70자1854      44   72362  22123122521600     0   37     1
# 1436757  20221231  부산70자1854      44   72362  22123122521700     0   22     1
# 1436758  20221231  부산70자1854      44   72362  22123122521800     0    0     0
#
# ...

# %%
print(bus_1854['급가속'].sum())
print(bus_1854['급출발'].sum())
print(bus_1854['급감속'].sum())
print(bus_1854['급정지'].sum())
# Out:
# 1483
# 135
# 1092
# 470

# %%
bus_1860 = df.query('번호판 == "부산70자1860"')
bus_1860
# Out:
#                날짜        번호판  일일주행거리   누적주행거리          정보발생일시  차량속도  RPM
# 1436759  20221201  부산70자1860       0  1074993  22120108104400     0  121  \
# 1436760  20221201  부산70자1860       0  1074993  22120108104500     0  121
# 1436761  20221201  부산70자1860       0  1074993  22120108104600     0  119
# 1436762  20221201  부산70자1860       0  1074993  22120108104700     0  173
# 1436763  20221201  부산70자1860       0  1074993  22120108104800     0  275
# ...           ...        ...     ...      ...             ...   ...  ...
# 2873323  20221231  부산70자1860     220  1080898  22123121562700     0    0
# 2873324  20221231  부산70자1860     220  1080898  22123121562800     0    0
# 2873325  20221231  부산70자1860     220  1080898  22123121562900     0    0
# 2873326  20221231  부산70자1860     220  1080898  22123121563000     0    0
# 2873327  20221231  부산70자1860     220  1080898  22123121563100     0    0
#
#          브레이크       GPS_X      GPS_Y  방위각  가속도_X  가속도_Y  급가속  급출발  급감속  급정지
# ...

# %%
print(bus_1860['급가속'].sum())
print(bus_1860['급출발'].sum())
print(bus_1860['급감속'].sum())
print(bus_1860['급정지'].sum())
# Out:
# 1961
# 150
# 2371
# 741

# %%
bus_1893 = df.query('번호판 == "부산70자1893"')
bus_1893
# Out:
#                날짜        번호판  일일주행거리   누적주행거리          정보발생일시  차량속도  RPM
# 2873328  20221201  부산70자1893       0  2022752  22120104254100     0  185  \
# 2873329  20221201  부산70자1893       0  2022752  22120104254200     0  246
# 2873330  20221201  부산70자1893       0  2022752  22120104254300     0  827
# 2873331  20221201  부산70자1893       0  2022752  22120104254400     0  592
# 2873332  20221201  부산70자1893       0  2022752  22120104254500     0  556
# ...           ...        ...     ...      ...             ...   ...  ...
# 4359148  20221231  부산70자1893     221  2022973  22123123434100     0    0
# 4359149  20221231  부산70자1893     221  2022973  22123123434200     0    0
# 4359150  20221231  부산70자1893     221  2022973  22123123434300     0    0
# 4359151  20221231  부산70자1893     221  2022973  22123123434400     0    0
# 4359152  20221231  부산70자1893     221  2022973  22123123434500     0    0
#
#          브레이크       GPS_X      GPS_Y  방위각  가속도_X  가속도_Y  급가속  급출발  급감속  급정지
# ...

# %%
print(bus_1893['급가속'].sum())
print(bus_1893['급출발'].sum())
print(bus_1893['급감속'].sum())
print(bus_1893['급정지'].sum())
# Out:
# 23394
# 9942
# 5678
# 7206

# %%
bus_1894 = df.query('번호판 == "부산70자1894"')
bus_1894
# Out:
#                날짜        번호판  일일주행거리   누적주행거리          정보발생일시  차량속도  RPM
# 4359153  20221201  부산70자1894       0  3089222  22120105083200     0  570  \
# 4359154  20221201  부산70자1894       0  3089222  22120105083300     0  561
# 4359155  20221201  부산70자1894       0  3089222  22120105083400     0  571
# 4359156  20221201  부산70자1894       0  3089222  22120105083500     0  570
# 4359157  20221201  부산70자1894       0  3089222  22120105083600     0  593
# ...           ...        ...     ...      ...             ...   ...  ...
# 5948207  20221231  부산70자1894     176  3095705  22123121033800     0  331
# 5948208  20221231  부산70자1894     176  3095705  22123121033900     0   59
# 5948209  20221231  부산70자1894     176  3095705  22123121034000     0    0
# 5948210  20221231  부산70자1894     176  3095705  22123121034100     0    0
# 5948211  20221231  부산70자1894     176  3095705  22123121034200     0    0
#
#          브레이크       GPS_X      GPS_Y  방위각  가속도_X  가속도_Y  급가속  급출발  급감속  급정지
# ...

# %%
print(bus_1894['급가속'].sum())
print(bus_1894['급출발'].sum())
print(bus_1894['급감속'].sum())
print(bus_1894['급정지'].sum())
# Out:
# 3496
# 235
# 643
# 359

# %%
y_1854 = bus_1854['급가속']
bus_1854 = bus_1854[['차량속도', 'RPM', '가속도_X', '가속도_Y']]
bus_1854
# Out:
#          차량속도  RPM  가속도_X  가속도_Y
# 0           0  193   -6.3    0.7
# 1           0  388   -7.9    1.6
# 2           0  777   -8.9    2.2
# 3           0  638   -6.6    0.8
# 4           0  461   -7.1    0.8
# ...       ...  ...    ...    ...
# 1436754     0  557   -6.7    0.5
# 1436755     0  223   -6.8    0.8
# 1436756     0   37   -6.8    0.7
# 1436757     0   22   -6.2    0.3
# 1436758     0    0   -6.0    0.2
#
# [1436759 rows x 4 columns]

# %%
from sklearn.decomposition import PCA

n_components = 4
whiten = False
random_state = 42

pca = PCA(n_components=n_components, whiten=whiten, random_state=random_state)

# %%
X_train_PCA = pca.fit_transform(bus_1854)
X_train_PCA = pd.DataFrame(data=X_train_PCA, index=bus_1854.index)

# %%
X_train_PCA
# Out:
#                   0          1         2         3
# 0       -677.301882  -5.850710 -0.502291 -0.100874
# 1       -482.386092  -0.194193  1.064552  1.223520
# 2        -93.557467  11.294725  2.450099  2.087044
# 3       -232.499265   7.377631  0.291588  0.236651
# 4       -409.419880   2.073721  0.181309  0.686464
# ...             ...        ...       ...       ...
# 1436754 -313.463198   4.974482 -0.081799  0.400831
# 1436755 -647.314493  -4.994949 -0.229611  0.357255
# 1436756 -833.231831 -10.529195 -0.583463  0.352558
# 1436757 -848.226110 -10.916031 -1.150489 -0.116973
# 1436758 -870.216636 -11.553017 -1.331047 -0.285533
#
# [1436759 rows x 4 columns]

# %%
# 라이브러리 불러오기
'''메인 라이브러리'''
import numpy as np
import pandas as pd
import os, time, pickle, gzip

'''시각화 관련 라이브러리'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

'''데이터 준비 관련 라이브러리'''
from sklearn import preprocessing as pp

# %matplotlib inline

# %%
def scatterPlot(xDF, yDF, algoName):
    tempDF = pd.DataFrame(data=xDF.loc[:,0:1], index=xDF.index)
    tempDF = pd.concat((tempDF,yDF), axis=1, join="inner")
    tempDF.columns = ["First Vector", "Second Vector", "Label"]
    sns.lmplot(x="First Vector", y="Second Vector", hue="Label", \
               data=tempDF, fit_reg=False)
    ax = plt.gca()
    ax.set_title("Separation of Observations using "+algoName)

# %%
scatterPlot(X_train_PCA, y_1854, 'PCA')

# %%
y_1893 = bus_1893['급가속']
bus_1893 = bus_1893[['차량속도', 'RPM', '가속도_X', '가속도_Y']]
bus_1893
# Out:
#          차량속도  RPM  가속도_X  가속도_Y
# 2873328     0  185    9.4    0.1
# 2873329     0  246   -6.2    0.1
# 2873330     0  827   -6.2    0.1
# 2873331     0  592   10.4    0.1
# 2873332     0  556   10.4    0.1
# ...       ...  ...    ...    ...
# 4359148     0    0   11.0    0.1
# 4359149     0    0   11.0    0.1
# 4359150     0    0  -11.6    0.1
# 4359151     0    0  -11.6    0.1
# 4359152     0    0  -11.6    0.1
#
# [1485825 rows x 4 columns]

# %%
X_train_PCA = pca.fit_transform(bus_1893)
X_train_PCA = pd.DataFrame(data=X_train_PCA, index=bus_1893.index)

# %%
X_train_PCA
# Out:
#                   0          1          2         3
# 2873328 -659.665431  -0.815222  12.987764  1.346633
# 2873329 -598.686634  -3.077370  -2.499651  0.362282
# 2873330  -17.789384 -13.996352  -2.111014  0.460798
# 2873331 -252.736741  -8.392626  14.255409  1.479407
# 2873332 -288.730375  -7.716063  14.231329  1.473303
# ...             ...        ...        ...       ...
# 4359148 -844.631645   2.775998  14.456654  1.417284
# 4359149 -844.631645   2.775998  14.456654  1.417284
# 4359150 -844.646734   1.159593  -8.039356 -0.023747
# 4359151 -844.646734   1.159593  -8.039356 -0.023747
# 4359152 -844.646734   1.159593  -8.039356 -0.023747
#
# [1485825 rows x 4 columns]

# %%
scatterPlot(X_train_PCA, y_1893, 'PCA')

# %%
y_1860 = bus_1860['급가속']
bus_1860 = bus_1860[['차량속도', 'RPM', '가속도_X', '가속도_Y']]
bus_1860
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\project\driving-record-analysis-for-web-service\flask\venv\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\Desktop\project\driving-record-analysis-for-web-service\flask\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Desktop\project\driving-record-analysis-for-web-service\flask\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '급가속'
#
# ...

# %%
X_train_PCA = pca.fit_transform(bus_1860)
X_train_PCA = pd.DataFrame(data=X_train_PCA, index=bus_1860.index)
X_train_PCA
# Out:
#                   0         1         2         3
# 1436759 -715.405604  6.515493  0.064009  0.117522
# 1436760 -715.405443  6.510670 -0.134002  0.145239
# 1436761 -717.404708  6.562393 -0.150864  0.045331
# 1436762 -663.426634  5.025774 -0.279972  0.708418
# 1436763 -561.469401  2.064324 -0.401227  0.902438
# ...             ...       ...       ...       ...
# 2873323 -836.354825  9.971164 -0.719075 -0.568754
# 2873324 -836.354825  9.971164 -0.719075 -0.568754
# 2873325 -836.354715  9.977490 -0.705391 -0.469897
# 2873326 -836.354635  9.975079 -0.804397 -0.456038
# 2873327 -836.354305  9.994060 -0.763345 -0.159467
#
# [1436569 rows x 4 columns]

# %%
scatterPlot(X_train_PCA, y_1860, 'PCA')

# %%
y_1894 = bus_1894['급가속']
bus_1894 = bus_1894[['차량속도', 'RPM', '가속도_X', '가속도_Y']]
bus_1894
# Out:
#          차량속도  RPM  가속도_X  가속도_Y
# 4359153     0  570   -7.0   -2.4
# 4359154     0  561   -7.2   -2.5
# 4359155     0  571   -7.3   -2.8
# 4359156     0  570   -7.5   -3.0
# 4359157     0  593   -7.6   -2.9
# ...       ...  ...    ...    ...
# 5948207     0  331   -5.7   -1.2
# 5948208     0   59   -5.8   -1.4
# 5948209     0    0   -5.4   -1.0
# 5948210     0    0   -5.4   -0.9
# 5948211     0    0   -5.3   -0.9
#
# [1589059 rows x 4 columns]

# %%
X_train_PCA = pca.fit_transform(bus_1894)
X_train_PCA = pd.DataFrame(data=X_train_PCA, index=bus_1894.index)
X_train_PCA
# Out:
#                   0          1         2         3
# 4359153 -303.419263  -5.097952  1.412782 -0.338515
# 4359154 -312.415121  -4.821626  1.603417 -0.447219
# 4359155 -302.419005  -5.103013  1.910360 -0.381842
# 4359156 -303.418187  -5.058824  2.185582 -0.444571
# 4359157 -280.428031  -5.727234  2.152882 -0.602292
# ...             ...        ...       ...       ...
# 5948207 -542.319449   1.793729 -0.284273  0.336009
# 5948208 -814.202790   9.754842 -0.054025  0.594077
# 5948209 -873.178329  11.449792 -0.602712  0.772669
# 5948210 -873.178428  11.448049 -0.687530  0.719726
# 5948211 -873.178524  11.442315 -0.740309  0.804469
#
# [1589059 rows x 4 columns]

# %%
scatterPlot(X_train_PCA, y_1894, 'PCA')

# %%
from sklearn import preprocessing as pp
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
def anomalyScores(originalDF, reducedDF):
    loss = np.sum((np.array(originalDF)-np.array(reducedDF))**2, axis=1)
    loss = pd.Series(data=loss,index=originalDF.index)
    loss = (loss-np.min(loss))/(np.max(loss)-np.min(loss))
    return loss

# %%
def plotResults(trueLabels, anomalyScores, returnPreds = False):
    preds = pd.concat([trueLabels, anomalyScores], axis=1)
    preds.columns = ['trueLabel', 'anomalyScore']
    precision, recall, thresholds = \
        precision_recall_curve(preds['trueLabel'],preds['anomalyScore'])
    average_precision = \
        average_precision_score(preds['trueLabel'],preds['anomalyScore'])

    plt.step(recall, precision, color='k', alpha=0.7, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])

    plt.title('Precision-Recall curve: Average Precision = \
    {0:0.2f}'.format(average_precision))

    fpr, tpr, thresholds = roc_curve(preds['trueLabel'], \
                                     preds['anomalyScore'])
    areaUnderROC = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
    plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic: \
    Area under the curve = {0:0.2f}'.format(areaUnderROC))
    plt.legend(loc="lower right")
    plt.show()

    if returnPreds==True:
        return preds

# %%
X_train_PCA_inverse = pca.inverse_transform(X_train_PCA)
X_train_PCA_inverse = pd.DataFrame(data=X_train_PCA_inverse, \
                                   index=X.index)
